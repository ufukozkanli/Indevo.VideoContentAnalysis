# %%
# %cd "TensorFlow-2.x-YOLOv3"
# !pwd
# Out:
# [Errno 2] No such file or directory: 'TensorFlow-2.x-YOLOv3'
# /media/data/projects/protekBase/test/codes/TensorFlow-2.x-YOLOv3
# /media/data/projects/protekBase/test/codes/TensorFlow-2.x-YOLOv3

# %%
def add_module_path():
    dir_path="../extent/embed"
    import sys,os        
    path=os.path.abspath(dir_path)
    
    if not path in sys.path:
        sys.path.append(path)
    print(sys.path)
    
add_module_path()
# Out:
# ['/envs/testYolo/lib/python36.zip', '/envs/testYolo/lib/python3.6', '/envs/testYolo/lib/python3.6/lib-dynload', '', '/envs/testYolo/lib/python3.6/site-packages', '/envs/testYolo/lib/python3.6/site-packages/IPython/extensions', '/home/ufukozkanli/.ipython', '/media/data/projects/protekBase/test/codes/extent/embed']

# %%
# !nvidia-smi
# Out:
# Sun Oct 11 21:12:14 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 20%   35C    P8    17W / 250W |  10809MiB / 11176MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:03:00.0 Off |                  N/A |
# | 23%   35C    P8     9W / 250W |   8278MiB / 11178MiB |      0%      Default |
# ...

# %%
import importlib

# %%
import importlib

import object_tracker
#import tracker_save as ts
#import detection_demo

#importlib.reload(tracker_save)
#importlib.reload(object_tracker)
# Out:
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# VIDEO PROPERTIES:FrameCount:107461	Width:400	Height:300	Fps:24
# Time: 6369.13ms, Detection FPS: 0.2, total FPS: 0.2
# Time: 3242.93ms, Detection FPS: 0.3, total FPS: 0.3
# Time: 2198.24ms, Detection FPS: 0.5, total FPS: 0.4
# Time: 1673.77ms, Detection FPS: 0.6, total FPS: 0.6
# Time: 1360.37ms, Detection FPS: 0.7, total FPS: 0.7
# Time: 1151.19ms, Detection FPS: 0.9, total FPS: 0.8
# Time: 1001.74ms, Detection FPS: 1.0, total FPS: 1.0
# Time: 889.86ms, Detection FPS: 1.1, total FPS: 1.1
# Time: 801.94ms, Detection FPS: 1.2, total FPS: 1.2
# Time: 733.91ms, Detection FPS: 1.4, total FPS: 1.3
# Time: 676.90ms, Detection FPS: 1.5, total FPS: 1.4
# Time: 628.70ms, Detection FPS: 1.6, total FPS: 1.5
# Time: 588.40ms, Detection FPS: 1.7, total FPS: 1.6
# Time: 554.10ms, Detection FPS: 1.8, total FPS: 1.7
# Time: 524.30ms, Detection FPS: 1.9, total FPS: 1.8
# Time: 497.55ms, Detection FPS: 2.0, total FPS: 1.9
# ...

# %%
#import video_summary
#importlib.reload(tracker_save)
importlib.reload(video_summary)
